# %% [markdown]
# # Sentiment Analysis
#
# ## Using XGBoost in SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# As our first example of using Amazon's SageMaker service we will construct a random tree model to predict the sentiment of a movie review. You may have seen a version of this example in a pervious lesson although it would have been done using the sklearn package. Instead, we will be using the XGBoost package as it is provided to us by Amazon.
#
# ## Instructions
#
# Some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this notebook. You will not need to modify the included code beyond what is requested. Sections that begin with '**TODO**' in the header indicate that you need to complete or implement some portion within them. Instructions will be provided for each section and the specifics of the implementation are marked in the code block with a `# TODO: ...` comment. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there may be questions for you to answer which relate to the task and your implementation. Each section where you will answer a question is preceded by a '**Question:**' header. Carefully read each question and provide your answer below the '**Answer:**' header by editing the Markdown cell.
#
# > **Note**: Code and Markdown cells can be executed using the **Shift+Enter** keyboard shortcut. In addition, a cell can be edited by typically clicking it (double-click for Markdown cells) or by pressing **Enter** while it is highlighted.

# %% [markdown]
# ## Step 1: Downloading the data
#
# The dataset we are going to use is very popular among researchers in Natural Language Processing, usually referred to as the [IMDb dataset](http://ai.stanford.edu/~amaas/data/sentiment/). It consists of movie reviews from the website [imdb.com](http://www.imdb.com/), each labeled as either '**pos**itive', if the reviewer enjoyed the film, or '**neg**ative' otherwise.
#
# > Maas, Andrew L., et al. [Learning Word Vectors for Sentiment Analysis](http://ai.stanford.edu/~amaas/data/sentiment/). In _Proceedings of the 49th Annual Meeting of the Association for Computational Linguistics: Human Language Technologies_. Association for Computational Linguistics, 2011.
#
# We begin by using some Jupyter Notebook magic to download and extract the dataset.

# %%
# %mkdir ../data
# !wget -O ../data/aclImdb_v1.tar.gz http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# !tar -zxf ../data/aclImdb_v1.tar.gz -C ../data
# Out:
# mkdir: cannot create directory ‘../data’: File exists
# --2020-08-24 07:00:37--  http://ai.stanford.edu/~amaas/data/sentiment/aclImdb_v1.tar.gz
# Resolving ai.stanford.edu (ai.stanford.edu)... 171.64.68.10
# Connecting to ai.stanford.edu (ai.stanford.edu)|171.64.68.10|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 84125825 (80M) [application/x-gzip]
# Saving to: ‘../data/aclImdb_v1.tar.gz’
#
# ../data/aclImdb_v1. 100%[===================>]  80.23M  4.41MB/s    in 21s
#
# 2020-08-24 07:00:59 (3.76 MB/s) - ‘../data/aclImdb_v1.tar.gz’ saved [84125825/84125825]

# %% [markdown]
# ## Step 2: Preparing the data
#
# The data we have downloaded is split into various files, each of which contains a single review. It will be much easier going forward if we combine these individual files into two large files, one for training and one for testing.

# %%
import os
import glob

def read_imdb_data(data_dir='../data/aclImdb'):
    data = {}
    labels = {}
    
    for data_type in ['train', 'test']:
        data[data_type] = {}
        labels[data_type] = {}
        
        for sentiment in ['pos', 'neg']:
            data[data_type][sentiment] = []
            labels[data_type][sentiment] = []
            
            path = os.path.join(data_dir, data_type, sentiment, '*.txt')
            files = glob.glob(path)
            
            for f in files:
                with open(f) as review:
                    data[data_type][sentiment].append(review.read())
                    # Here we represent a positive review by '1' and a negative review by '0'
                    labels[data_type][sentiment].append(1 if sentiment == 'pos' else 0)
                    
            assert len(data[data_type][sentiment]) == len(labels[data_type][sentiment]), \
                    "{}/{} data size does not match labels size".format(data_type, sentiment)
                
    return data, labels

# %%
data, labels = read_imdb_data()
print("IMDB reviews: train = {} pos / {} neg, test = {} pos / {} neg".format(
            len(data['train']['pos']), len(data['train']['neg']),
            len(data['test']['pos']), len(data['test']['neg'])))
# Out:
# IMDB reviews: train = 12500 pos / 12500 neg, test = 12500 pos / 12500 neg

# %%
from sklearn.utils import shuffle

def prepare_imdb_data(data, labels):
    """Prepare training and test sets from IMDb movie reviews."""
    
    #Combine positive and negative reviews and labels
    data_train = data['train']['pos'] + data['train']['neg']
    data_test = data['test']['pos'] + data['test']['neg']
    labels_train = labels['train']['pos'] + labels['train']['neg']
    labels_test = labels['test']['pos'] + labels['test']['neg']
    
    #Shuffle reviews and corresponding labels within training and test sets
    data_train, labels_train = shuffle(data_train, labels_train)
    data_test, labels_test = shuffle(data_test, labels_test)
    
    # Return a unified training data, test data, training labels, test labets
    return data_train, data_test, labels_train, labels_test

# %%
train_X, test_X, train_y, test_y = prepare_imdb_data(data, labels)
print("IMDb reviews (combined): train = {}, test = {}".format(len(train_X), len(test_X)))
# Out:
# IMDb reviews (combined): train = 25000, test = 25000

# %%
train_X[100]
# Out:
# 'Very bad but watchable science fiction film that suffers from abominable special effects, poor acting, and a ridiculous story. The film opens with a spaceship returning from exploration on Mars with a woman and a man with green slime on his arm. She, through some hokey plot contrivances, begins to tell what happened on this fateful trip as almost all the tapes seemed to be magnetically wiped off. Four astronauts take on this journey: a military type played by Gerald Mohr, a poor man\'s Humphrey Bogart who enjoys saying the word "Irish" and has the acting savvy of a codfish, then there is Naura Hayden, a beautiful redhead and only female crew member on flight with three men wearing the most formfitting suits possible to accentuate all her curves, next, Les Tremaine, a wonderful character actor from cheap sci-fi films like this as the egghead, and last, Jack Kruschen as Sammy - the guy from Brooklyn with jokes and doesn\'t seem too bright although chosen for his expertise in electronics. None of these performers are really any good, and all of them say their dialog with little conviction. Watch Tremaine as he utters that scientific nonsense! Really, the best out of the four is Kruschen - and that really says a lot about this film. But bad acting aside, the movie just falls apart when they land on Mars via flashback. The Angry Red Planet had a real cheap budget because Mars is really the American Southwest with a heavy red tint over it. When the story calls for something that might look Martian, there are drawings placed with a heavy red tint over them. You can tell they are drawings The monsters are perhaps even worse as we get a Bat-rat-spider with a size upwards of 40 feet that looks like some kids got together piecing dead animals together. The other significant creature is a giant amoeba with an oscillating eye. Whew! These are bad. There is a nice drawing of a Martian city, but there just was not enough of this in the film. Despite all these big problems, The Angry Red Planet is a fun bad film. It is really fascinating to see how far we have come as a civilization. Most of the stuff they used in the movie is so outdated. One guy is using an electric razor with a cord and I thought they can get to Mars but they are still using cords. Director Ib Melchior gives an interesting look to much of the film even with the budgetary constraints, but the story by him and Sid Pink doesn\'t fly. And how bout that ending with the music and the psychedelic colors? Groovy man!'

# %% [markdown]
# ## Step 3: Processing the data
#
# Now that we have our training and testing datasets merged and ready to use, we need to start processing the raw data into something that will be useable by our machine learning algorithm. To begin with, we remove any html formatting that may appear in the reviews and perform some standard natural language processing in order to homogenize the data.

# %%
import nltk
nltk.download("stopwords")
from nltk.corpus import stopwords
from nltk.stem.porter import *
stemmer = PorterStemmer()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/ec2-user/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import re
from bs4 import BeautifulSoup

def review_to_words(review):
    text = BeautifulSoup(review, "html.parser").get_text() # Remove HTML tags
    text = re.sub(r"[^a-zA-Z0-9]", " ", text.lower()) # Convert to lower case
    words = text.split() # Split string into words
    words = [w for w in words if w not in stopwords.words("english")] # Remove stopwords
    words = [PorterStemmer().stem(w) for w in words] # stem
    
    return words

# %%
import pickle

cache_dir = os.path.join("../cache", "sentiment_analysis")  # where to store cache files
os.makedirs(cache_dir, exist_ok=True)  # ensure cache directory exists

def preprocess_data(data_train, data_test, labels_train, labels_test,
                    cache_dir=cache_dir, cache_file="preprocessed_data.pkl"):
    """Convert each review to words; read from cache if available."""

    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = pickle.load(f)
            print("Read preprocessed data from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Preprocess training and test data to obtain words for each review
        #words_train = list(map(review_to_words, data_train))
        #words_test = list(map(review_to_words, data_test))
        words_train = [review_to_words(review) for review in data_train]
        words_test = [review_to_words(review) for review in data_test]
        
        # Write to cache file for future runs
        if cache_file is not None:
            cache_data = dict(words_train=words_train, words_test=words_test,
                              labels_train=labels_train, labels_test=labels_test)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                pickle.dump(cache_data, f)
            print("Wrote preprocessed data to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        words_train, words_test, labels_train, labels_test = (cache_data['words_train'],
                cache_data['words_test'], cache_data['labels_train'], cache_data['labels_test'])
    
    return words_train, words_test, labels_train, labels_test

# %% [markdown]
# ##### Warning cell below may take longer to run

# %%
# Preprocess data 12.30-1.15
train_X, test_X, train_y, test_y = preprocess_data(train_X, test_X, train_y, test_y)
# Out:
# Wrote preprocessed data to cache file: preprocessed_data.pkl

# %% [markdown]
# ### Extract Bag-of-Words features
#
# For the model we will be implementing, rather than using the reviews directly, we are going to transform each review into a Bag-of-Words feature representation. Keep in mind that 'in the wild' we will only have access to the training set so our transformer can only use the training set to construct a representation.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
import joblib
# joblib is an enhanced version of pickle that is more efficient for storing NumPy arrays

def extract_BoW_features(words_train, words_test, vocabulary_size=5000,
                         cache_dir=cache_dir, cache_file="bow_features.pkl"):
    """Extract Bag-of-Words for a given set of documents, already preprocessed into words."""
    
    # If cache_file is not None, try to read from it first
    cache_data = None
    if cache_file is not None:
        try:
            with open(os.path.join(cache_dir, cache_file), "rb") as f:
                cache_data = joblib.load(f)
            print("Read features from cache file:", cache_file)
        except:
            pass  # unable to read from cache, but that's okay
    
    # If cache is missing, then do the heavy lifting
    if cache_data is None:
        # Fit a vectorizer to training documents and use it to transform them
        # NOTE: Training documents have already been preprocessed and tokenized into words;
        #       pass in dummy functions to skip those steps, e.g. preprocessor=lambda x: x
        vectorizer = CountVectorizer(max_features=vocabulary_size,
                preprocessor=lambda x: x, tokenizer=lambda x: x)  # already preprocessed
        features_train = vectorizer.fit_transform(words_train).toarray()

        # Apply the same vectorizer to transform the test documents (ignore unknown words)
        features_test = vectorizer.transform(words_test).toarray()
        
        # NOTE: Remember to convert the features using .toarray() for a compact representation
        
        # Write to cache file for future runs (store vocabulary as well)
        if cache_file is not None:
            vocabulary = vectorizer.vocabulary_
            cache_data = dict(features_train=features_train, features_test=features_test,
                             vocabulary=vocabulary)
            with open(os.path.join(cache_dir, cache_file), "wb") as f:
                joblib.dump(cache_data, f)
            print("Wrote features to cache file:", cache_file)
    else:
        # Unpack data loaded from cache file
        features_train, features_test, vocabulary = (cache_data['features_train'],
                cache_data['features_test'], cache_data['vocabulary'])
    
    # Return both the extracted features as well as the vocabulary
    return features_train, features_test, vocabulary

# %%
# Extract Bag of Words features for both training and test datasets
train_X, test_X, vocabulary = extract_BoW_features(train_X, test_X)
# Out:
# Wrote features to cache file: bow_features.pkl

# %% [markdown]
# ## Step 4: Classification using XGBoost
#
# Now that we have created the feature representation of our training (and testing) data, it is time to start setting up and using the XGBoost classifier provided by SageMaker.
#
# ### (TODO) Writing the dataset
#
# The XGBoost classifier that we will be using requires the dataset to be written to a file and stored using Amazon S3. To do this, we will start by splitting the training dataset into two parts, the data we will train the model with and a validation set. Then, we will write those datasets to a file and upload the files to S3. In addition, we will write the test set input to a file and upload the file to S3. This is so that we can use SageMakers Batch Transform functionality to test our model once we've fit it.

# %%
import pandas as pd
import sklearn.model_selection

# TODO: Split the train_X and train_y arrays into the DataFrames val_X, train_X and val_y, train_y. Make sure that
#       val_X and val_y contain 10 000 entires while train_X and train_y contain the remaining 15 000 entries.
val_X = pd.DataFrame(train_X[:10000])
train_X = pd.DataFrame(train_X[10000:])

val_y = pd.DataFrame(train_y[:10000])
train_y = pd.DataFrame(train_y[10000:])

# %% [markdown]
# The documentation for the XGBoost algorithm in SageMaker requires that the saved datasets should contain no headers or index and that for the training and validation data, the label should occur first for each sample.
#
# For more information about this and other algorithms, the SageMaker developer documentation can be found on __[Amazon's website.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
# First we make sure that the local directory in which we'd like to store the training and validation csv files exists.
data_dir = '../data/xgboost'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# First, save the test data to test.csv in the data_dir directory. Note that we do not save the associated ground truth
# labels, instead we will use them later to compare with our model output.

pd.DataFrame(test_X).to_csv(os.path.join(data_dir, 'test.csv'), header=False, index=False)

# TODO: Save the training and validation data to train.csv and validation.csv in the data_dir directory.
#       Make sure that the files you create are in the correct format.
pd.concat([train_y, train_X], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)
pd.concat([val_y, val_X], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)

# %%
# To save a bit of memory we can set test_X, train_X, val_X, train_y and val_y to None.

test_X = train_X = val_X = train_y = val_y = None

# %% [markdown]
# ### (TODO) Uploading Training / Validation files to S3
#
# Amazon's S3 service allows us to store files that can be access by both the built-in training models such as the XGBoost model we will be using as well as custom models such as the one we will see a little later.
#
# For this, and most other tasks we will be doing using SageMaker, there are two methods we could use. The first is to use the low level functionality of SageMaker which requires knowing each of the objects involved in the SageMaker environment. The second is to use the high level functionality in which certain choices have been made on the user's behalf. The low level approach benefits from allowing the user a great deal of flexibility while the high level approach makes development much quicker. For our purposes we will opt to use the high level approach although using the low-level approach is certainly an option.
#
# Recall the method `upload_data()` which is a member of object representing our current SageMaker session. What this method does is upload the data to the default bucket (which is created if it does not exist) into the path described by the key_prefix variable. To see this for yourself, once you have uploaded the data files, go to the S3 console and look to see where the files have been uploaded.
#
# For additional resources, see the __[SageMaker API documentation](http://sagemaker.readthedocs.io/en/latest/)__ and in addition the __[SageMaker Developer Guide.](https://docs.aws.amazon.com/sagemaker/latest/dg/)__

# %%
import sagemaker

session = sagemaker.Session() # Store the current SageMaker session

# S3 prefix (which folder will we use)
prefix = 'sentiment-xgboost'

# TODO: Upload the test.csv, train.csv and validation.csv files which are contained in data_dir to S3 using sess.upload_data().
test_location = session.upload_data(os.path.join(data_dir, 'test.csv'), key_prefix=prefix)
val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ### (TODO) Creating the XGBoost model
#
# Now that the data has been uploaded it is time to create the XGBoost model. To begin with, we need to do some setup. At this point it is worth discussing what a model is in SageMaker. It is easiest to think of a model of comprising three different objects in the SageMaker ecosystem, which interact with one another.
#
# - Model Artifacts
# - Training Code (Container)
# - Inference Code (Container)
#
# The Model Artifacts are what you might think of as the actual model itself. For example, if you were building a neural network, the model artifacts would be the weights of the various layers. In our case, for an XGBoost model, the artifacts are the actual trees that are created during training.
#
# The other two objects, the training code and the inference code are then used the manipulate the training artifacts. More precisely, the training code uses the training data that is provided and creates the model artifacts, while the inference code uses the model artifacts to make predictions on new data.
#
# The way that SageMaker runs the training and inference code is by making use of Docker containers. For now, think of a container as being a way of packaging code up so that dependencies aren't an issue.

# %%
from sagemaker import get_execution_role

# Our current execution role is require when creating the model as the training
# and inference code will need to access the model artifacts.
role = get_execution_role()

# %%
# We need to retrieve the location of the container which is provided by Amazon for using XGBoost.
# As a matter of convenience, the training and inference code both use the same container.
from sagemaker.amazon.amazon_estimator import get_image_uri

container = get_image_uri(session.boto_region_name, 'xgboost', '1.0-1')
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.

# %%
# TODO: Create a SageMaker estimator using the container location determined in the previous cell.
#       It is recommended that you use a single training instance of type ml.m4.xlarge. It is also
#       recommended that you use 's3://{}/{}/output'.format(session.default_bucket(), prefix) as the
#       output path.

xgb = sagemaker.estimator.Estimator(container,
                                   role,
                                   train_instance_count=1,
                                   train_instance_type='ml.m4.xlarge',
                                   output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                   sagemaker_session=session)


# TODO: Set the XGBoost hyperparameters in the xgb object. Don't forget that in this case we have a binary
#       label so we should be using the 'binary:logistic' objective.
xgb.set_hyperparameters(max_depth=5, 
                        eta=0.3, 
                        gamma=5,
                        subsample=0.7,
                        objective='binary:logistic',
                        num_round=500)
# Out:
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# ### Fit the XGBoost model
#
# Now that our model has been set up we simply need to attach the training and validation datasets and then ask SageMaker to set up the computation.

# %%
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='csv')
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %%
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2020-08-24 07:56:16 Starting - Starting the training job...
# 2020-08-24 07:56:19 Starting - Launching requested ML instances......
# 2020-08-24 07:57:23 Starting - Preparing the instances for training......
# 2020-08-24 07:58:41 Downloading - Downloading input data
# 2020-08-24 07:58:41 Training - Downloading the training image...
# 2020-08-24 07:59:16 Training - Training image download completed. Training in progress...INFO:sagemaker-containers:Imported framework sagemaker_xgboost_container.training
# INFO:sagemaker-containers:Failed to parse hyperparameter objective value binary:logistic to Json.
# Returning the value itself
# INFO:sagemaker-containers:No GPUs detected (normal if no gpus installed)
# INFO:sagemaker_xgboost_container.training:Running XGBoost Sagemaker in algorithm mode
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# INFO:root:Determined delimiter of CSV input is ','
# [07:59:19] 5000x5000 matrix with 25000000 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# INFO:root:Determined delimiter of CSV input is ','
# [07:59:21] 10000x5000 matrix with 50000000 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# INFO:root:Single node training.
# INFO:root:Train matrix has 5000 rows
# INFO:root:Validation matrix has 10000 rows
# [07:59:21] WARNING: /workspace/src/learner.cc:328:
# Parameters: { num_round } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [0]#011train-error:0.29580#011validation-error:0.30870
# [1]#011train-error:0.27620#011validation-error:0.28630
# [2]#011train-error:0.25700#011validation-error:0.27780
# [3]#011train-error:0.24140#011validation-error:0.26720
# [4]#011train-error:0.22860#011validation-error:0.25770
# [5]#011train-error:0.21640#011validation-error:0.25010
# [6]#011train-error:0.21140#011validation-error:0.24590
# [7]#011train-error:0.20740#011validation-error:0.24430
# [8]#011train-error:0.19500#011validation-error:0.23540
# [9]#011train-error:0.19100#011validation-error:0.23690
# [10]#011train-error:0.18500#011validation-error:0.22900
# [11]#011train-error:0.18240#011validation-error:0.22550
# [12]#011train-error:0.17580#011validation-error:0.22120
# [13]#011train-error:0.17140#011validation-error:0.21520
# [14]#011train-error:0.16400#011validation-error:0.21240
# [15]#011train-error:0.15880#011validation-error:0.21080
# [16]#011train-error:0.15160#011validation-error:0.20660
# [17]#011train-error:0.15220#011validation-error:0.20400
# [18]#011train-error:0.15040#011validation-error:0.20320
# [19]#011train-error:0.14920#011validation-error:0.20210
# [20]#011train-error:0.14640#011validation-error:0.19860
# [21]#011train-error:0.14080#011validation-error:0.19840
# [22]#011train-error:0.13900#011validation-error:0.19660
# [23]#011train-error:0.13560#011validation-error:0.19710
# [24]#011train-error:0.13620#011validation-error:0.19490
# [25]#011train-error:0.13260#011validation-error:0.19670
# [26]#011train-error:0.13140#011validation-error:0.19510
# [27]#011train-error:0.12700#011validation-error:0.19390
# [28]#011train-error:0.12420#011validation-error:0.19180
# [29]#011train-error:0.12580#011validation-error:0.18990
# [30]#011train-error:0.12280#011validation-error:0.18870
# [31]#011train-error:0.11920#011validation-error:0.18590
# [32]#011train-error:0.11760#011validation-error:0.18390
# [33]#011train-error:0.11440#011validation-error:0.18310
# [34]#011train-error:0.11460#011validation-error:0.18360
# [35]#011train-error:0.11400#011validation-error:0.18280
# [36]#011train-error:0.11400#011validation-error:0.18150
# [37]#011train-error:0.11240#011validation-error:0.18180
# [38]#011train-error:0.10980#011validation-error:0.18190
# [39]#011train-error:0.10960#011validation-error:0.18040
# [40]#011train-error:0.10900#011validation-error:0.18000
# [41]#011train-error:0.10780#011validation-error:0.17930
# [42]#011train-error:0.10540#011validation-error:0.17920
# [43]#011train-error:0.10600#011validation-error:0.17960
# [44]#011train-error:0.10560#011validation-error:0.17890
# [45]#011train-error:0.10320#011validation-error:0.17740
# [46]#011train-error:0.10320#011validation-error:0.17560
# [47]#011train-error:0.10080#011validation-error:0.17530
# [48]#011train-error:0.10020#011validation-error:0.17400
# [49]#011train-error:0.10140#011validation-error:0.17320
# [50]#011train-error:0.10060#011validation-error:0.17210
# [51]#011train-error:0.10040#011validation-error:0.17140
# [52]#011train-error:0.09840#011validation-error:0.17100
# [53]#011train-error:0.09780#011validation-error:0.17040
# [54]#011train-error:0.09720#011validation-error:0.16950
# [55]#011train-error:0.09660#011validation-error:0.16860
# [56]#011train-error:0.09720#011validation-error:0.16800
# [57]#011train-error:0.09480#011validation-error:0.16860
# [58]#011train-error:0.09420#011validation-error:0.16790
# [59]#011train-error:0.09480#011validation-error:0.16730
# [60]#011train-error:0.09260#011validation-error:0.16740
# [61]#011train-error:0.09260#011validation-error:0.16780
# [62]#011train-error:0.09160#011validation-error:0.16740
# [63]#011train-error:0.08900#011validation-error:0.16730
# [64]#011train-error:0.08740#011validation-error:0.16650
# [65]#011train-error:0.08680#011validation-error:0.16610
# [66]#011train-error:0.08500#011validation-error:0.16660
# [67]#011train-error:0.08440#011validation-error:0.16500
# [68]#011train-error:0.08380#011validation-error:0.16540
# [69]#011train-error:0.08420#011validation-error:0.16560
# [70]#011train-error:0.08300#011validation-error:0.16440
# [71]#011train-error:0.08320#011validation-error:0.16520
# [72]#011train-error:0.08340#011validation-error:0.16530
# [73]#011train-error:0.07980#011validation-error:0.16390
# [74]#011train-error:0.07940#011validation-error:0.16460
# [75]#011train-error:0.07900#011validation-error:0.16470
# [76]#011train-error:0.07800#011validation-error:0.16470
# [77]#011train-error:0.07820#011validation-error:0.16530
# [78]#011train-error:0.07800#011validation-error:0.16570
# [79]#011train-error:0.07840#011validation-error:0.16490
# [80]#011train-error:0.07920#011validation-error:0.16300
# [81]#011train-error:0.07940#011validation-error:0.16310
# [82]#011train-error:0.07980#011validation-error:0.16400
# [83]#011train-error:0.07860#011validation-error:0.16330
# [84]#011train-error:0.07860#011validation-error:0.16340
# [85]#011train-error:0.07740#011validation-error:0.16330
# [86]#011train-error:0.07740#011validation-error:0.16350
# [87]#011train-error:0.07720#011validation-error:0.16370
# [88]#011train-error:0.07760#011validation-error:0.16490
# [89]#011train-error:0.07680#011validation-error:0.16460
# [90]#011train-error:0.07660#011validation-error:0.16270
# [91]#011train-error:0.07660#011validation-error:0.16330
# [92]#011train-error:0.07660#011validation-error:0.16380
# [93]#011train-error:0.07560#011validation-error:0.16240
# [94]#011train-error:0.07400#011validation-error:0.16240
# [95]#011train-error:0.07320#011validation-error:0.16200
# [96]#011train-error:0.07200#011validation-error:0.16260
# [97]#011train-error:0.07340#011validation-error:0.16230
# [98]#011train-error:0.07240#011validation-error:0.16040
# [99]#011train-error:0.07240#011validation-error:0.15990
# [100]#011train-error:0.07240#011validation-error:0.15980
# [101]#011train-error:0.07340#011validation-error:0.16010
# [102]#011train-error:0.07340#011validation-error:0.16100
# [103]#011train-error:0.07340#011validation-error:0.16120
# [104]#011train-error:0.07340#011validation-error:0.16100
# [105]#011train-error:0.07320#011validation-error:0.16100
# [106]#011train-error:0.07360#011validation-error:0.16180
# [107]#011train-error:0.07360#011validation-error:0.16190
# [108]#011train-error:0.07380#011validation-error:0.16130
# [109]#011train-error:0.07380#011validation-error:0.16150
# [110]#011train-error:0.07420#011validation-error:0.16220
# [111]#011train-error:0.07420#011validation-error:0.16120
# [112]#011train-error:0.07440#011validation-error:0.16160
# [113]#011train-error:0.07440#011validation-error:0.16100
# [114]#011train-error:0.07400#011validation-error:0.16150
# [115]#011train-error:0.07400#011validation-error:0.16150
# [116]#011train-error:0.07400#011validation-error:0.16230
# [117]#011train-error:0.07420#011validation-error:0.16200
# [118]#011train-error:0.07400#011validation-error:0.16210
# [119]#011train-error:0.07320#011validation-error:0.16200
# [120]#011train-error:0.07240#011validation-error:0.16130
# [121]#011train-error:0.06960#011validation-error:0.16090
# [122]#011train-error:0.06960#011validation-error:0.16080
# [123]#011train-error:0.06980#011validation-error:0.16100
# [124]#011train-error:0.07040#011validation-error:0.16020
# [125]#011train-error:0.07060#011validation-error:0.15990
# [126]#011train-error:0.07080#011validation-error:0.16050
# [127]#011train-error:0.07100#011validation-error:0.16050
# [128]#011train-error:0.07100#011validation-error:0.16030
# [129]#011train-error:0.07100#011validation-error:0.16040
# [130]#011train-error:0.07040#011validation-error:0.16020
# [131]#011train-error:0.07040#011validation-error:0.16030
# [132]#011train-error:0.07020#011validation-error:0.16040
# [133]#011train-error:0.06980#011validation-error:0.16060
# [134]#011train-error:0.06940#011validation-error:0.16070
# [135]#011train-error:0.07020#011validation-error:0.16030
# [136]#011train-error:0.06880#011validation-error:0.16030
# [137]#011train-error:0.06900#011validation-error:0.16030
# [138]#011train-error:0.06940#011validation-error:0.16020
# [139]#011train-error:0.06760#011validation-error:0.16020
# [140]#011train-error:0.06720#011validation-error:0.16020
# [141]#011train-error:0.06780#011validation-error:0.16060
# [142]#011train-error:0.06760#011validation-error:0.16090
# [143]#011train-error:0.06700#011validation-error:0.16000
# [144]#011train-error:0.06700#011validation-error:0.16000
# [145]#011train-error:0.06620#011validation-error:0.15920
# [146]#011train-error:0.06640#011validation-error:0.15920
# [147]#011train-error:0.06620#011validation-error:0.15920
# [148]#011train-error:0.06660#011validation-error:0.16010
# [149]#011train-error:0.06700#011validation-error:0.16060
# [150]#011train-error:0.06640#011validation-error:0.15920
# [151]#011train-error:0.06600#011validation-error:0.15960
# [152]#011train-error:0.06700#011validation-error:0.16050
# [153]#011train-error:0.06700#011validation-error:0.16030
# [154]#011train-error:0.06700#011validation-error:0.16050
# [155]#011train-error:0.06640#011validation-error:0.16060
# [156]#011train-error:0.06560#011validation-error:0.16040
# [157]#011train-error:0.06500#011validation-error:0.15960
# [158]#011train-error:0.06500#011validation-error:0.15960
# [159]#011train-error:0.06500#011validation-error:0.15960
# [160]#011train-error:0.06500#011validation-error:0.15860
# [161]#011train-error:0.06440#011validation-error:0.15810
# [162]#011train-error:0.06460#011validation-error:0.15830
# [163]#011train-error:0.06380#011validation-error:0.15780
# [164]#011train-error:0.06380#011validation-error:0.15790
# [165]#011train-error:0.06400#011validation-error:0.15800
# [166]#011train-error:0.06500#011validation-error:0.15840
# [167]#011train-error:0.06440#011validation-error:0.15810
# [168]#011train-error:0.06440#011validation-error:0.15820
# [169]#011train-error:0.06420#011validation-error:0.15770
# [170]#011train-error:0.06420#011validation-error:0.15750
# [171]#011train-error:0.06420#011validation-error:0.15780
# [172]#011train-error:0.06420#011validation-error:0.15750
# [173]#011train-error:0.06440#011validation-error:0.15840
# [174]#011train-error:0.06440#011validation-error:0.15830
# [175]#011train-error:0.06440#011validation-error:0.15840
# [176]#011train-error:0.06440#011validation-error:0.15850
# [177]#011train-error:0.06520#011validation-error:0.15670
# [178]#011train-error:0.06520#011validation-error:0.15660
# [179]#011train-error:0.06560#011validation-error:0.15670
# [180]#011train-error:0.06520#011validation-error:0.15660
# [181]#011train-error:0.06500#011validation-error:0.15700
# [182]#011train-error:0.06500#011validation-error:0.15690
# [183]#011train-error:0.06520#011validation-error:0.15700
# [184]#011train-error:0.06520#011validation-error:0.15710
# [185]#011train-error:0.06520#011validation-error:0.15720
# [186]#011train-error:0.06500#011validation-error:0.15820
# [187]#011train-error:0.06420#011validation-error:0.15800
# [188]#011train-error:0.06460#011validation-error:0.15810
# [189]#011train-error:0.06440#011validation-error:0.15800
# [190]#011train-error:0.06460#011validation-error:0.15810
# [191]#011train-error:0.06460#011validation-error:0.15820
# [192]#011train-error:0.06440#011validation-error:0.15820
# [193]#011train-error:0.06460#011validation-error:0.15820
# [194]#011train-error:0.06440#011validation-error:0.15810
# [195]#011train-error:0.06420#011validation-error:0.15760
# [196]#011train-error:0.06420#011validation-error:0.15750
# [197]#011train-error:0.06440#011validation-error:0.15770
# [198]#011train-error:0.06420#011validation-error:0.15760
# [199]#011train-error:0.06440#011validation-error:0.15780
# [200]#011train-error:0.06460#011validation-error:0.15810
# [201]#011train-error:0.06460#011validation-error:0.15820
# [202]#011train-error:0.06440#011validation-error:0.15800
# [203]#011train-error:0.06460#011validation-error:0.15810
# [204]#011train-error:0.06440#011validation-error:0.15820
# [205]#011train-error:0.06420#011validation-error:0.15780
# [206]#011train-error:0.06400#011validation-error:0.15750
# [207]#011train-error:0.06420#011validation-error:0.15770
# [208]#011train-error:0.06340#011validation-error:0.15720
# [209]#011train-error:0.06340#011validation-error:0.15720
# [210]#011train-error:0.06360#011validation-error:0.15720
# [211]#011train-error:0.06400#011validation-error:0.15750
# [212]#011train-error:0.06360#011validation-error:0.15730
# [213]#011train-error:0.06400#011validation-error:0.15750
# [214]#011train-error:0.06360#011validation-error:0.15710
# [215]#011train-error:0.06360#011validation-error:0.15710
# [216]#011train-error:0.06400#011validation-error:0.15750
# [217]#011train-error:0.06280#011validation-error:0.15680
# [218]#011train-error:0.06300#011validation-error:0.15640
# [219]#011train-error:0.06280#011validation-error:0.15670
# [220]#011train-error:0.06360#011validation-error:0.15730
# [221]#011train-error:0.06360#011validation-error:0.15710
# [222]#011train-error:0.06400#011validation-error:0.15750
# [223]#011train-error:0.06440#011validation-error:0.15740
# [224]#011train-error:0.06440#011validation-error:0.15730
# [225]#011train-error:0.06340#011validation-error:0.15730
# [226]#011train-error:0.06160#011validation-error:0.15590
# [227]#011train-error:0.06120#011validation-error:0.15570
# [228]#011train-error:0.06160#011validation-error:0.15590
# [229]#011train-error:0.06160#011validation-error:0.15590
# [230]#011train-error:0.06120#011validation-error:0.15590
# [231]#011train-error:0.06120#011validation-error:0.15590
# [232]#011train-error:0.06120#011validation-error:0.15540
# [233]#011train-error:0.06120#011validation-error:0.15580
# [234]#011train-error:0.06120#011validation-error:0.15560
# [235]#011train-error:0.06120#011validation-error:0.15540
# [236]#011train-error:0.06160#011validation-error:0.15520
# [237]#011train-error:0.06160#011validation-error:0.15500
# [238]#011train-error:0.06100#011validation-error:0.15590
# [239]#011train-error:0.06120#011validation-error:0.15520
# [240]#011train-error:0.06160#011validation-error:0.15520
# [241]#011train-error:0.06120#011validation-error:0.15490
# [242]#011train-error:0.06140#011validation-error:0.15500
# [243]#011train-error:0.06140#011validation-error:0.15480
# [244]#011train-error:0.06080#011validation-error:0.15560
# [245]#011train-error:0.06060#011validation-error:0.15550
# [246]#011train-error:0.06040#011validation-error:0.15550
# [247]#011train-error:0.06060#011validation-error:0.15550
# [248]#011train-error:0.06060#011validation-error:0.15560
# [249]#011train-error:0.06140#011validation-error:0.15480
# [250]#011train-error:0.06080#011validation-error:0.15590
# [251]#011train-error:0.06040#011validation-error:0.15640
# [252]#011train-error:0.06040#011validation-error:0.15640
# [253]#011train-error:0.06040#011validation-error:0.15640
# [254]#011train-error:0.06040#011validation-error:0.15620
# [255]#011train-error:0.06060#011validation-error:0.15600
# [256]#011train-error:0.06040#011validation-error:0.15620
# [257]#011train-error:0.06040#011validation-error:0.15640
# [258]#011train-error:0.06040#011validation-error:0.15650
# [259]#011train-error:0.06040#011validation-error:0.15640
# [260]#011train-error:0.06080#011validation-error:0.15510
# [261]#011train-error:0.06020#011validation-error:0.15560
# [262]#011train-error:0.06040#011validation-error:0.15540
# [263]#011train-error:0.06040#011validation-error:0.15560
# [264]#011train-error:0.06040#011validation-error:0.15550
# [265]#011train-error:0.06080#011validation-error:0.15540
# [266]#011train-error:0.06080#011validation-error:0.15510
# [267]#011train-error:0.06080#011validation-error:0.15520
# [268]#011train-error:0.06080#011validation-error:0.15510
# [269]#011train-error:0.06040#011validation-error:0.15540
# [270]#011train-error:0.06080#011validation-error:0.15520
# [271]#011train-error:0.06060#011validation-error:0.15470
# [272]#011train-error:0.06060#011validation-error:0.15480
# [273]#011train-error:0.06000#011validation-error:0.15500
# [274]#011train-error:0.06000#011validation-error:0.15480
# [275]#011train-error:0.06040#011validation-error:0.15460
# [276]#011train-error:0.06000#011validation-error:0.15500
# [277]#011train-error:0.06000#011validation-error:0.15500
# [278]#011train-error:0.06040#011validation-error:0.15460
# [279]#011train-error:0.06040#011validation-error:0.15470
# [280]#011train-error:0.06000#011validation-error:0.15510
# [281]#011train-error:0.06040#011validation-error:0.15470
# [282]#011train-error:0.05980#011validation-error:0.15480
# [283]#011train-error:0.06040#011validation-error:0.15460
# [284]#011train-error:0.06020#011validation-error:0.15460
# [285]#011train-error:0.06000#011validation-error:0.15500
# [286]#011train-error:0.05980#011validation-error:0.15490
# [287]#011train-error:0.06000#011validation-error:0.15470
# [288]#011train-error:0.06000#011validation-error:0.15470
# [289]#011train-error:0.06040#011validation-error:0.15460
# [290]#011train-error:0.06040#011validation-error:0.15460
# [291]#011train-error:0.06020#011validation-error:0.15480
# [292]#011train-error:0.05980#011validation-error:0.15410
# [293]#011train-error:0.05980#011validation-error:0.15440
# [294]#011train-error:0.05960#011validation-error:0.15450
# [295]#011train-error:0.05960#011validation-error:0.15440
# [296]#011train-error:0.06000#011validation-error:0.15440
# [297]#011train-error:0.06020#011validation-error:0.15440
# [298]#011train-error:0.05980#011validation-error:0.15420
# [299]#011train-error:0.05980#011validation-error:0.15410
# [300]#011train-error:0.05960#011validation-error:0.15450
# [301]#011train-error:0.05980#011validation-error:0.15520
# [302]#011train-error:0.05960#011validation-error:0.15520
# [303]#011train-error:0.05980#011validation-error:0.15510
# [304]#011train-error:0.05920#011validation-error:0.15550
# [305]#011train-error:0.05960#011validation-error:0.15530
# [306]#011train-error:0.05980#011validation-error:0.15510
# [307]#011train-error:0.05960#011validation-error:0.15530
# [308]#011train-error:0.05960#011validation-error:0.15530
# [309]#011train-error:0.05920#011validation-error:0.15560
# [310]#011train-error:0.05940#011validation-error:0.15560
# [311]#011train-error:0.05920#011validation-error:0.15560
# [312]#011train-error:0.05920#011validation-error:0.15560
# [313]#011train-error:0.05940#011validation-error:0.15560
# [314]#011train-error:0.05920#011validation-error:0.15560
# [315]#011train-error:0.05940#011validation-error:0.15550
# [316]#011train-error:0.05940#011validation-error:0.15540
# [317]#011train-error:0.05920#011validation-error:0.15560
# [318]#011train-error:0.05940#011validation-error:0.15560
# [319]#011train-error:0.05960#011validation-error:0.15590
# [320]#011train-error:0.05900#011validation-error:0.15550
# [321]#011train-error:0.05900#011validation-error:0.15530
# [322]#011train-error:0.05900#011validation-error:0.15550
# [323]#011train-error:0.05880#011validation-error:0.15520
# [324]#011train-error:0.05880#011validation-error:0.15530
# [325]#011train-error:0.05800#011validation-error:0.15550
# [326]#011train-error:0.05800#011validation-error:0.15520
# [327]#011train-error:0.05820#011validation-error:0.15550
# [328]#011train-error:0.05840#011validation-error:0.15560
# [329]#011train-error:0.05940#011validation-error:0.15460
# [330]#011train-error:0.05840#011validation-error:0.15410
# [331]#011train-error:0.05820#011validation-error:0.15520
# [332]#011train-error:0.05820#011validation-error:0.15480
# [333]#011train-error:0.05820#011validation-error:0.15520
# [334]#011train-error:0.05780#011validation-error:0.15440
# [335]#011train-error:0.05760#011validation-error:0.15470
# [336]#011train-error:0.05720#011validation-error:0.15520
# [337]#011train-error:0.05720#011validation-error:0.15510
# [338]#011train-error:0.05740#011validation-error:0.15530
# [339]#011train-error:0.05740#011validation-error:0.15490
# [340]#011train-error:0.05720#011validation-error:0.15510
# [341]#011train-error:0.05720#011validation-error:0.15500
# [342]#011train-error:0.05720#011validation-error:0.15470
# [343]#011train-error:0.05720#011validation-error:0.15460
# [344]#011train-error:0.05720#011validation-error:0.15470
# [345]#011train-error:0.05760#011validation-error:0.15490
# [346]#011train-error:0.05700#011validation-error:0.15390
# [347]#011train-error:0.05700#011validation-error:0.15400
# [348]#011train-error:0.05820#011validation-error:0.15430
# [349]#011train-error:0.05780#011validation-error:0.15430
# [350]#011train-error:0.05720#011validation-error:0.15390
# [351]#011train-error:0.05700#011validation-error:0.15400
# [352]#011train-error:0.05660#011validation-error:0.15480
# [353]#011train-error:0.05680#011validation-error:0.15500
# [354]#011train-error:0.05660#011validation-error:0.15470
# [355]#011train-error:0.05660#011validation-error:0.15470
# [356]#011train-error:0.05660#011validation-error:0.15480
# [357]#011train-error:0.05680#011validation-error:0.15490
# [358]#011train-error:0.05680#011validation-error:0.15490
# [359]#011train-error:0.05680#011validation-error:0.15490
# [360]#011train-error:0.05660#011validation-error:0.15530
# [361]#011train-error:0.05660#011validation-error:0.15550
# [362]#011train-error:0.05660#011validation-error:0.15520
# [363]#011train-error:0.05680#011validation-error:0.15540
# [364]#011train-error:0.05660#011validation-error:0.15520
# [365]#011train-error:0.05660#011validation-error:0.15510
# [366]#011train-error:0.05640#011validation-error:0.15550
# [367]#011train-error:0.05620#011validation-error:0.15580
# [368]#011train-error:0.05660#011validation-error:0.15560
# [369]#011train-error:0.05660#011validation-error:0.15560
# [370]#011train-error:0.05640#011validation-error:0.15570
# [371]#011train-error:0.05660#011validation-error:0.15570
# [372]#011train-error:0.05660#011validation-error:0.15560
# [373]#011train-error:0.05660#011validation-error:0.15570
# [374]#011train-error:0.05660#011validation-error:0.15570
# [375]#011train-error:0.05680#011validation-error:0.15580
# [376]#011train-error:0.05660#011validation-error:0.15560
# [377]#011train-error:0.05660#011validation-error:0.15560
# [378]#011train-error:0.05660#011validation-error:0.15570
# [379]#011train-error:0.05640#011validation-error:0.15570
# [380]#011train-error:0.05620#011validation-error:0.15580
# [381]#011train-error:0.05620#011validation-error:0.15570
# [382]#011train-error:0.05640#011validation-error:0.15560
# [383]#011train-error:0.05660#011validation-error:0.15560
# [384]#011train-error:0.05620#011validation-error:0.15580
# [385]#011train-error:0.05600#011validation-error:0.15600
# [386]#011train-error:0.05600#011validation-error:0.15600
# [387]#011train-error:0.05600#011validation-error:0.15600
# [388]#011train-error:0.05640#011validation-error:0.15590
# [389]#011train-error:0.05600#011validation-error:0.15600
# [390]#011train-error:0.05620#011validation-error:0.15610
# [391]#011train-error:0.05620#011validation-error:0.15560
# [392]#011train-error:0.05520#011validation-error:0.15610
# [393]#011train-error:0.05500#011validation-error:0.15570
# [394]#011train-error:0.05500#011validation-error:0.15570
# [395]#011train-error:0.05500#011validation-error:0.15570
# [396]#011train-error:0.05520#011validation-error:0.15590
# [397]#011train-error:0.05520#011validation-error:0.15560
# [398]#011train-error:0.05500#011validation-error:0.15590
# [399]#011train-error:0.05500#011validation-error:0.15560
# [400]#011train-error:0.05560#011validation-error:0.15560
# [401]#011train-error:0.05520#011validation-error:0.15590
# [402]#011train-error:0.05500#011validation-error:0.15560
# [403]#011train-error:0.05540#011validation-error:0.15570
# [404]#011train-error:0.05520#011validation-error:0.15570
# [405]#011train-error:0.05520#011validation-error:0.15610
# [406]#011train-error:0.05520#011validation-error:0.15590
# [407]#011train-error:0.05520#011validation-error:0.15570
# [408]#011train-error:0.05460#011validation-error:0.15580
# [409]#011train-error:0.05500#011validation-error:0.15560
# [410]#011train-error:0.05500#011validation-error:0.15570
# [411]#011train-error:0.05500#011validation-error:0.15570
# [412]#011train-error:0.05500#011validation-error:0.15590
# [413]#011train-error:0.05520#011validation-error:0.15610
# [414]#011train-error:0.05520#011validation-error:0.15590
# [415]#011train-error:0.05520#011validation-error:0.15580
# [416]#011train-error:0.05520#011validation-error:0.15610
# [417]#011train-error:0.05520#011validation-error:0.15570
# [418]#011train-error:0.05500#011validation-error:0.15560
# [419]#011train-error:0.05520#011validation-error:0.15620
# [420]#011train-error:0.05520#011validation-error:0.15590
# [421]#011train-error:0.05500#011validation-error:0.15570
# [422]#011train-error:0.05520#011validation-error:0.15610
# [423]#011train-error:0.05520#011validation-error:0.15630
# [424]#011train-error:0.05520#011validation-error:0.15590
# [425]#011train-error:0.05500#011validation-error:0.15570
# [426]#011train-error:0.05520#011validation-error:0.15610
# [427]#011train-error:0.05500#011validation-error:0.15570
# [428]#011train-error:0.05500#011validation-error:0.15590
# [429]#011train-error:0.05520#011validation-error:0.15590
# [430]#011train-error:0.05520#011validation-error:0.15610
# [431]#011train-error:0.05520#011validation-error:0.15590
# [432]#011train-error:0.05540#011validation-error:0.15540
# [433]#011train-error:0.05560#011validation-error:0.15510
# [434]#011train-error:0.05500#011validation-error:0.15510
# [435]#011train-error:0.05540#011validation-error:0.15520
# [436]#011train-error:0.05560#011validation-error:0.15520
# [437]#011train-error:0.05500#011validation-error:0.15510
# [438]#011train-error:0.05520#011validation-error:0.15520
# [439]#011train-error:0.05600#011validation-error:0.15420
# [440]#011train-error:0.05600#011validation-error:0.15420
# [441]#011train-error:0.05600#011validation-error:0.15360
# [442]#011train-error:0.05640#011validation-error:0.15420
# [443]#011train-error:0.05620#011validation-error:0.15410
# [444]#011train-error:0.05620#011validation-error:0.15420
# [445]#011train-error:0.05620#011validation-error:0.15410
# [446]#011train-error:0.05620#011validation-error:0.15410
# [447]#011train-error:0.05620#011validation-error:0.15420
# [448]#011train-error:0.05600#011validation-error:0.15360
# [449]#011train-error:0.05560#011validation-error:0.15360
# [450]#011train-error:0.05560#011validation-error:0.15360
# [451]#011train-error:0.05560#011validation-error:0.15360
# [452]#011train-error:0.05600#011validation-error:0.15350
# [453]#011train-error:0.05620#011validation-error:0.15410
# [454]#011train-error:0.05640#011validation-error:0.15390
# [455]#011train-error:0.05640#011validation-error:0.15420
# [456]#011train-error:0.05600#011validation-error:0.15370
# [457]#011train-error:0.05580#011validation-error:0.15350
# [458]#011train-error:0.05560#011validation-error:0.15370
# [459]#011train-error:0.05560#011validation-error:0.15360
# [460]#011train-error:0.05560#011validation-error:0.15370
# [461]#011train-error:0.05540#011validation-error:0.15360
# [462]#011train-error:0.05560#011validation-error:0.15360
# [463]#011train-error:0.05640#011validation-error:0.15400
# [464]#011train-error:0.05620#011validation-error:0.15400
# [465]#011train-error:0.05620#011validation-error:0.15410
# [466]#011train-error:0.05640#011validation-error:0.15420
# [467]#011train-error:0.05620#011validation-error:0.15420
# [468]#011train-error:0.05640#011validation-error:0.15420
# [469]#011train-error:0.05640#011validation-error:0.15400
# [470]#011train-error:0.05620#011validation-error:0.15430
# [471]#011train-error:0.05620#011validation-error:0.15430
# [472]#011train-error:0.05620#011validation-error:0.15420
# [473]#011train-error:0.05620#011validation-error:0.15410
# [474]#011train-error:0.05620#011validation-error:0.15420
# [475]#011train-error:0.05640#011validation-error:0.15390
# [476]#011train-error:0.05640#011validation-error:0.15380
# [477]#011train-error:0.05620#011validation-error:0.15410
# [478]#011train-error:0.05620#011validation-error:0.15410
# [479]#011train-error:0.05580#011validation-error:0.15360
# [480]#011train-error:0.05600#011validation-error:0.15360
# [481]#011train-error:0.05540#011validation-error:0.15360
# [482]#011train-error:0.05560#011validation-error:0.15360
# [483]#011train-error:0.05580#011validation-error:0.15360
# [484]#011train-error:0.05600#011validation-error:0.15370
# [485]#011train-error:0.05640#011validation-error:0.15370
# [486]#011train-error:0.05600#011validation-error:0.15360
# [487]#011train-error:0.05600#011validation-error:0.15370
# [488]#011train-error:0.05600#011validation-error:0.15370
# [489]#011train-error:0.05600#011validation-error:0.15360
# [490]#011train-error:0.05600#011validation-error:0.15370
# [491]#011train-error:0.05460#011validation-error:0.15390
# [492]#011train-error:0.05460#011validation-error:0.15400
# [493]#011train-error:0.05460#011validation-error:0.15410
# [494]#011train-error:0.05500#011validation-error:0.15390
# [495]#011train-error:0.05460#011validation-error:0.15410
# [496]#011train-error:0.05520#011validation-error:0.15440
# [497]#011train-error:0.05420#011validation-error:0.15440
# [498]#011train-error:0.05420#011validation-error:0.15430
# [499]#011train-error:0.05420#011validation-error:0.15400
#
# 2020-08-24 08:02:58 Uploading - Uploading generated training model
# 2020-08-24 08:03:34 Completed - Training job completed
# Training seconds: 312
# Billable seconds: 312

# %% [markdown]
# ### (TODO) Testing the model
#
# Now that we've fit our XGBoost model, it's time to see how well it performs. To do this we will use SageMakers Batch Transform functionality. Batch Transform is a convenient way to perform inference on a large dataset in a way that is not realtime. That is, we don't necessarily need to use our model's results immediately and instead we can peform inference on a large number of samples. An example of this in industry might be peforming an end of month report. This method of inference can also be useful to us as it means to can perform inference on our entire test set.
#
# To perform a Batch Transformation we need to first create a transformer objects from our trained estimator object.

# %%
# TODO: Create a transformer object from the trained model. Using an instance count of 1 and an instance type of ml.m4.xlarge
#       should be more than enough.
xgb_transformer = xgb.transformer(instance_count=1, 
                                  instance_type='ml.m4.xlarge')
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Next we actually perform the transform job. When doing so we need to make sure to specify the type of data we are sending so that it is serialized correctly in the background. In our case we are providing our model with csv data so we specify `text/csv`. Also, if the test data that we have provided is too large to process all at once then we need to specify how the data file should be split up. Since each line is a single entry in our data set we tell SageMaker that it can split the input on each line.

# %%
# TODO: Start the transform job. Make sure to specify the content type and the split type of the test data.
xgb_transformer.transform(test_location, 
                          content_type='text/csv', 
                          split_type='Line')

# %% [markdown]
# Currently the transform job is running but it is doing so in the background. Since we wish to wait until the transform job is done and we would like a bit of feedback we can run the `wait()` method.

# %%
xgb_transformer.wait()
# Out:
# ..............................[2020-08-24:08:08:48:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:48:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:48:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# [2020-08-24:08:08:48:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:48:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:48:INFO] nginx config:
# worker_processes auto;
# daemon off;
# pid /tmp/nginx.pid;
# error_log  /dev/stderr;
#
# worker_rlimit_nofile 4096;
#
# events {
#   worker_connections 2048;
# }
#
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2020/08/24 08:08:48 [crit] 19#19: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [24/Aug/2020:08:08:48 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/08/24 08:08:48 [crit] 19#19: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [24/Aug/2020:08:08:48 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2020-08-24 08:08:48 +0000] [17] [INFO] Starting gunicorn 19.10.0
# [2020-08-24 08:08:48 +0000] [17] [INFO] Listening at: unix:/tmp/gunicorn.sock (17)
# http {
#   include /etc/nginx/mime.types;
#   default_type application/octet-stream;
#   access_log /dev/stdout combined;
#
#   upstream gunicorn {
#     server unix:/tmp/gunicorn.sock;
#   }
#
#   server {
#     listen 8080 deferred;
#     client_max_body_size 0;
#
#     keepalive_timeout 3;
#
#     location ~ ^/(ping|invocations|execution-parameters) {
#       proxy_set_header X-Forwarded-For $proxy_add_x_forwarded_for;
#       proxy_set_header Host $http_host;
#       proxy_redirect off;
#       proxy_read_timeout 60s;
#       proxy_pass http://gunicorn;
#     }
#
#     location / {
#       return 404 "{}";
#     }
#
#   }
# }
#
#
# 2020/08/24 08:08:48 [crit] 19#19: *1 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [24/Aug/2020:08:08:48 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# 2020/08/24 08:08:48 [crit] 19#19: *3 connect() to unix:/tmp/gunicorn.sock failed (2: No such file or directory) while connecting to upstream, client: 169.254.255.130, server: , request: "GET /ping HTTP/1.1", upstream: "http://unix:/tmp/gunicorn.sock:/ping", host: "169.254.255.131:8080"
# 169.254.255.130 - - [24/Aug/2020:08:08:48 +0000] "GET /ping HTTP/1.1" 502 182 "-" "Go-http-client/1.1"
# [2020-08-24 08:08:48 +0000] [17] [INFO] Starting gunicorn 19.10.0
# [2020-08-24 08:08:48 +0000] [17] [INFO] Listening at: unix:/tmp/gunicorn.sock (17)
# [2020-08-24 08:08:48 +0000] [17] [INFO] Using worker: gevent
# [2020-08-24 08:08:48 +0000] [24] [INFO] Booting worker with pid: 24
# [2020-08-24 08:08:48 +0000] [25] [INFO] Booting worker with pid: 25
# [2020-08-24 08:08:48 +0000] [29] [INFO] Booting worker with pid: 29
# [2020-08-24 08:08:49 +0000] [30] [INFO] Booting worker with pid: 30
# [2020-08-24 08:08:48 +0000] [17] [INFO] Using worker: gevent
# [2020-08-24 08:08:48 +0000] [24] [INFO] Booting worker with pid: 24
# [2020-08-24 08:08:48 +0000] [25] [INFO] Booting worker with pid: 25
# [2020-08-24 08:08:48 +0000] [29] [INFO] Booting worker with pid: 29
# [2020-08-24 08:08:49 +0000] [30] [INFO] Booting worker with pid: 30
# [2020-08-24:08:08:50:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:50:INFO] No GPUs detected (normal if no gpus installed)
# 169.254.255.130 - - [24/Aug/2020:08:08:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:50 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:51:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:51:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:50 +0000] "GET /ping HTTP/1.1" 200 0 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:50 +0000] "GET /execution-parameters HTTP/1.1" 200 84 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:51:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:51:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:51:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:51:INFO] No GPUs detected (normal if no gpus installed)
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:51:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12225 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12239 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12225 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12239 "-" "Go-http-client/1.1"
# 2020-08-24T08:08:50.827:[sagemaker logs]: MaxConcurrentTransforms=4, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12256 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12261 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12256 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:54 +0000] "POST /invocations HTTP/1.1" 200 12261 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:54:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12218 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12257 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12266 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12247 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:57:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:57:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:57:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:58:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12218 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12257 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12266 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:08:57 +0000] "POST /invocations HTTP/1.1" 200 12247 "-" "Go-http-client/1.1"
# [2020-08-24:08:08:57:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:57:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:57:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:08:58:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:03 +0000] "POST /invocations HTTP/1.1" 200 12269 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:03 +0000] "POST /invocations HTTP/1.1" 200 12300 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:04 +0000] "POST /invocations HTTP/1.1" 200 12226 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:04 +0000] "POST /invocations HTTP/1.1" 200 12276 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:03 +0000] "POST /invocations HTTP/1.1" 200 12269 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:03 +0000] "POST /invocations HTTP/1.1" 200 12300 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:04 +0000] "POST /invocations HTTP/1.1" 200 12226 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:04 +0000] "POST /invocations HTTP/1.1" 200 12276 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:04:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:07 +0000] "POST /invocations HTTP/1.1" 200 12274 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:07 +0000] "POST /invocations HTTP/1.1" 200 12262 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:07 +0000] "POST /invocations HTTP/1.1" 200 12274 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:07 +0000] "POST /invocations HTTP/1.1" 200 12262 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:07:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12260 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12260 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12258 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12277 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12284 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12258 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12277 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:10 +0000] "POST /invocations HTTP/1.1" 200 12284 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:10:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12262 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12287 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:13:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12266 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:13:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12262 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12287 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:13:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12266 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:13:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12277 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:13:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:14:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:13 +0000] "POST /invocations HTTP/1.1" 200 12277 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:13:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:14:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:16 +0000] "POST /invocations HTTP/1.1" 200 12269 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:16 +0000] "POST /invocations HTTP/1.1" 200 12252 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:16:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:16 +0000] "POST /invocations HTTP/1.1" 200 12256 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:16:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:17 +0000] "POST /invocations HTTP/1.1" 200 12259 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:17:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:17:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:16 +0000] "POST /invocations HTTP/1.1" 200 12269 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:16 +0000] "POST /invocations HTTP/1.1" 200 12252 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:16:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:16 +0000] "POST /invocations HTTP/1.1" 200 12256 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:16:INFO] Determined delimiter of CSV input is ','
# 169.254.255.130 - - [24/Aug/2020:08:09:17 +0000] "POST /invocations HTTP/1.1" 200 12259 "-" "Go-http-client/1.1"
# [2020-08-24:08:09:17:INFO] Determined delimiter of CSV input is ','
# [2020-08-24:08:09:17:INFO] Determined delimiter of CSV input is ','
#
# 169.254.255.130 - - [24/Aug/2020:08:09:22 +0000] "POST /invocations HTTP/1.1" 200 9122 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:22 +0000] "POST /invocations HTTP/1.1" 200 12266 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:22 +0000] "POST /invocations HTTP/1.1" 200 12220 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:23 +0000] "POST /invocations HTTP/1.1" 200 12257 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:22 +0000] "POST /invocations HTTP/1.1" 200 9122 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:22 +0000] "POST /invocations HTTP/1.1" 200 12266 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:22 +0000] "POST /invocations HTTP/1.1" 200 12220 "-" "Go-http-client/1.1"
# 169.254.255.130 - - [24/Aug/2020:08:09:23 +0000] "POST /invocations HTTP/1.1" 200 12257 "-" "Go-http-client/1.1"

# %% [markdown]
# Now the transform job has executed and the result, the estimated sentiment of each review, has been saved on S3. Since we would rather work on this file locally we can perform a bit of notebook magic to copy the file to the `data_dir`.

# %%
# !aws s3 cp --recursive $xgb_transformer.output_path $data_dir
# Out:
# download: s3://sagemaker-ap-south-1-714138043953/sagemaker-xgboost-2020-08-24-08-04-00-809/test.csv.out to ../data/xgboost/test.csv.out

# %% [markdown]
# The last step is now to read in the output from our model, convert the output to something a little more usable, in this case we want the sentiment to be either `1` (positive) or `0` (negative), and then compare to the ground truth labels.

# %%
predictions = pd.read_csv(os.path.join(data_dir, 'test.csv.out'), header=None)
predictions = [round(num) for num in predictions.squeeze().values]

# %%
from sklearn.metrics import accuracy_score
accuracy_score(test_y, predictions)
# Out:
# 0.84584

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir

# Similarly we will remove the files in the cache_dir directory and the directory itself
# !rm $cache_dir/*
# !rmdir $cache_dir
